# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

plt.rcParams['font.family'] = 'Malgun Gothic'
plt.rcParams['axes.unicode_minus'] = False

# %%
df = pd.read_csv('../미니프로젝트2_배구결과예측/공격종합.csv')
df
# Out:
#                                                Model  Accuracy
# 0                               Logistsic Regression     0.992
# 1                              Stacking(rf, lr, knn)     0.992
# 2  LightGBM(learning_rate = 0.1, m_estm = 100, , ...     0.975
# 3                              KNN(n_neighbors = 13)     0.958
# 4  RF(max_depth=10, max_features=0.8, min_samples...     0.941
# 5  Gradient Boost(learning_rate = 0.1, m_estm = 100)     0.924
# 6  Voting(lr, rf(max_depth = 8, max_features = 0....     0.900
# 7  Decision Tree(max_depth=12, min_samples_split ...     0.857
# 8  Xgboost(learning_rate=0.001, n_estimators=1000...     0.793

# %%
# 위 데이터를 bar 차트로 시각화하세요.
plt.figure(figsize=(10, 7))


x = df['Accuracy']
y = df['Model']
sns.barplot(x, y, palette= 'pastel')



plt.xlabel('Accuracy')
plt.ylabel('Model', fontsize = 12)
plt.title('각 Model별 Accuracy', fontsize = 16)


plt.show()
# Out:
# C:\Anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(

# %%
df2 = pd.read_csv('../미니프로젝트2_배구결과예측/공격따로.csv')
df2
# Out:
#                                                Model  Accuracy
# 0                              KNN(n_neighbors = 10)     0.975
# 1               Logistsic Regression(StandardScaler)     0.966
# 2                          Stacking(rf, lr_std, knn)     0.966
# 3  LightGBM(learning_rate = 0.1, m_estm = 100, su...     0.958
# 4  Gradient Boost(learning_rate = 0.1, m_estm = 1...     0.958
# 5  RF(max_depth=8, max_features = 0.8, min_sample...     0.941
# 6  Voting(lr(max_iter=1000), rf(max_depth = 8, ma...     0.933
# 7  Decision Tree(max_depth=6, min_samples_split =...     0.857
# 8  Xgboost(learning_rate=0.001, n_estimators=1000...     0.797

# %%
# 위 데이터를 bar 차트로 시각화하세요.
plt.figure(figsize=(10, 7))


x = df2['Accuracy']
y = df2['Model']
sns.barplot(x, y, palette= 'pastel')



plt.xlabel('Accuracy')
plt.ylabel('Model', fontsize = 12)
plt.title('각 Model별 Accuracy', fontsize = 16)


plt.show()
# Out:
# C:\Anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
